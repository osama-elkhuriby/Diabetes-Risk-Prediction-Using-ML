# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from keras.models import Sequential
from keras.layers import Dense
import pickle

# %% [markdown]
# # Reading Data

# %%
data = pd.read_csv("/content/diabetes.csv")
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Clean Data

# %%
print(data.isnull().sum())
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
medical_cols = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']

print("Zeros in columns:")
for col in medical_cols:
    zero_count = (data[col] == 0).sum()
    print(f"{col}: {zero_count} zeros")
# Out:
# Zeros in columns:
# Glucose: 5 zeros
# BloodPressure: 35 zeros
# SkinThickness: 227 zeros
# Insulin: 374 zeros
# BMI: 11 zeros

# %% [markdown]
# Replace zeros with average

# %%
data[medical_cols] = data[medical_cols].replace(0,np.nan)

simpel_imputer = SimpleImputer(strategy="median")
data[medical_cols] = simpel_imputer.fit_transform(data[medical_cols])

data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # Data Preprocessing

# %%
x = data.drop("Outcome", axis=1)
y = data["Outcome"]

# %%
x.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33

# %%
y.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %% [markdown]
# Data scaling

# %%
scaler = MinMaxScaler()
x = scaler.fit_transform(x)

# %% [markdown]
# Split Data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state= 42)

# %% [markdown]
# # Model

# %% [markdown]
# Logistic Regression

# %%
model_LogisticReg = LogisticRegression()
model_LogisticReg.fit(x_train,y_train)
print("Logistic Regression Score = ",model_LogisticReg.score(x_test,y_test))
# Out:
# Logistic Regression Score =  0.7792207792207793

# %% [markdown]
# Random Forest

# %%
model_RandomForest = RandomForestClassifier(random_state= 42)
model_RandomForest.fit(x_train,y_train)
print("Random Forest Score = ",model_RandomForest.score(x_test,y_test))
# Out:
# Random Forest Score =  0.7402597402597403

# %% [markdown]
# SVM

# %%
model_SVM = SVC(kernel="linear", random_state= 42)
model_SVM.fit(x_train,y_train)
print("SVM Score = ",model_SVM.score(x_test,y_test))
# Out:
# SVM Score =  0.7727272727272727

# %% [markdown]
# Using Neural Network

# %%
model_DL = Sequential([
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(1, activation='sigmoid') # binary
])
model_DL.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model_DL.fit(x = x_train, y = y_train, validation_split = 0.2,batch_size = 16, epochs = 30)


test_loss, test_accuracy = model_DL.evaluate(x_test, y_test)
print(f"Neural Network Test Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch 1/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - accuracy: 0.6755 - loss: 0.6734 - val_accuracy: 0.6098 - val_loss: 0.6796
# Epoch 2/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6627 - loss: 0.6552 - val_accuracy: 0.6098 - val_loss: 0.6652
# Epoch 3/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6755 - loss: 0.6377 - val_accuracy: 0.6098 - val_loss: 0.6472
# Epoch 4/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6729 - loss: 0.6235 - val_accuracy: 0.6423 - val_loss: 0.6286
# Epoch 5/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6598 - loss: 0.6149 - val_accuracy: 0.6585 - val_loss: 0.6127
# Epoch 6/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6719 - loss: 0.5972 - val_accuracy: 0.6911 - val_loss: 0.6007
# Epoch 7/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6692 - loss: 0.5953 - val_accuracy: 0.6992 - val_loss: 0.5872
# Epoch 8/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7025 - loss: 0.5687 - val_accuracy: 0.7154 - val_loss: 0.5711
# Epoch 9/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7341 - loss: 0.5514 - val_accuracy: 0.7236 - val_loss: 0.5599
# Epoch 10/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7227 - loss: 0.5477 - val_accuracy: 0.7154 - val_loss: 0.5519
# Epoch 11/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7375 - loss: 0.5352 - val_accuracy: 0.7236 - val_loss: 0.5463
# Epoch 12/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7643 - loss: 0.5037 - val_accuracy: 0.7398 - val_loss: 0.5296
# Epoch 13/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7445 - loss: 0.5362 - val_accuracy: 0.7480 - val_loss: 0.5233
# Epoch 14/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7524 - loss: 0.5032 - val_accuracy: 0.7561 - val_loss: 0.5148
# Epoch 15/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7316 - loss: 0.5119 - val_accuracy: 0.7561 - val_loss: 0.5103
# Epoch 16/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7468 - loss: 0.5048 - val_accuracy: 0.7561 - val_loss: 0.5048
# Epoch 17/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7540 - loss: 0.5004 - val_accuracy: 0.7561 - val_loss: 0.5021
# Epoch 18/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7787 - loss: 0.4635 - val_accuracy: 0.7480 - val_loss: 0.4941
# Epoch 19/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7737 - loss: 0.4817 - val_accuracy: 0.7561 - val_loss: 0.4940
# Epoch 20/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7367 - loss: 0.5047 - val_accuracy: 0.7561 - val_loss: 0.4896
# Epoch 21/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7441 - loss: 0.5095 - val_accuracy: 0.7480 - val_loss: 0.4929
# Epoch 22/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7498 - loss: 0.4997 - val_accuracy: 0.7642 - val_loss: 0.4831
# Epoch 23/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7447 - loss: 0.5156 - val_accuracy: 0.7561 - val_loss: 0.4828
# Epoch 24/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7497 - loss: 0.5106 - val_accuracy: 0.7561 - val_loss: 0.4852
# Epoch 25/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7679 - loss: 0.4898 - val_accuracy: 0.7561 - val_loss: 0.4836
# Epoch 26/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7719 - loss: 0.4770 - val_accuracy: 0.7642 - val_loss: 0.4776
# Epoch 27/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7518 - loss: 0.4888 - val_accuracy: 0.7561 - val_loss: 0.4769
# Epoch 28/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7678 - loss: 0.4661 - val_accuracy: 0.7724 - val_loss: 0.4722
# Epoch 29/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7338 - loss: 0.4768 - val_accuracy: 0.7642 - val_loss: 0.4755
# Epoch 30/30
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7784 - loss: 0.4610 - val_accuracy: 0.7642 - val_loss: 0.4739
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7224 - loss: 0.5188
# Neural Network Test Accuracy: 0.7468

# %% [markdown]
# # Deployment

# %%
file_name = "Final_project.sav"
pickle.dump(model_LogisticReg,open(file_name,'wb'))

# %% [markdown]
# Get info from user to pridect

# %%
sex = input("Male Or Women : ")
if sex == "Women" or sex == "women" :
    p = int(input("Enter the number of Pregnancies : "))
else:
    p = 0
g = int(input("Num of Glucose : "))
b = int(input("Num of Blood Pressure : "))
s = int(input("Num of Skin Thickness : "))
i = int(input("Num of Insulin : "))
bmi = float(input("Your BMI : "))
print("Diabetes Pedigree Function = (1 + coefficient of relationship) × family_diabetes_prevalence")
d =  float(input("Your Diabetes Pedigree Function : "))
a = int(input("Your Age : "))
# Out:
# Male Or Women : male
# Num of Glucose : 50
# Num of Blood Pressure : 99
# Num of Skin Thickness : 36
# Num of Skin Insulin : 12
# Your BMI : 45
# Diabetes Pedigree Function = (1 + coefficient of relationship) × family_diabetes_prevalence
# Your Diabetes Pedigree Function : 2
# Your Age : 25

# %% [markdown]
# Show the prediction

# %%
loaded_model = pickle.load(open('/content/Final_project.sav','rb'))
result = loaded_model.predict([[p,g,b,s,i,bmi,d,a]])

if result ==  [1] :
    print("You are a diabetic patient")
else:
    print("You are not a diabetic patient")
# Out:
# You are a diabetic patient
